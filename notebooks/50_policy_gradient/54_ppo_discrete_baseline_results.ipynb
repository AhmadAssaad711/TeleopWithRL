# %% [markdown]
# # Discrete PPO baseline results
#
# Dedicated result notebook for [`54_ppo_discrete_baseline.ipynb`](54_ppo_discrete_baseline.ipynb). Only the best recorded mode from the executed notebook output is shown: switched dynamics.
#
# This is archival evidence from the embedded notebook output. The original PPO-discrete result directory is not tracked in the current checkout.
#
# ## Best recorded result
#
# | Model | Mode | Tracking RMSE [mm] | Pre-switch [mm] | Post-switch [mm] | Transparency RMSE [W] | Pre-switch [W] | Post-switch [W] | Invalid episodes |
# |---|---|---:|---:|---:|---:|---:|---:|---:|
# | `PPO Discrete_baseline_eqgrad_t40_tr40_nojerk` | switched dynamics | **8.328** | 13.473 | 3.645 | 2.310 | 3.639 | 1.176 | 0.0% |

# %% [markdown]
# ## Evaluation graph
#
# Evaluation is shown with bar graphs only.
#
# ![PPO discrete evaluation bars](../../results_index/figures/ppo_discrete_evaluation_bars.png)

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = next(p for p in [Path.cwd().resolve(), *Path.cwd().resolve().parents] if (p / 'results_index').exists())
ppod = pd.DataFrame([{'model': 'PPO Discrete_baseline_eqgrad_t40_tr40_nojerk', 'mode': 'switched dynamics', 'tracking_rmse_mm': 8.328, 'pre_switch_tracking_mm': 13.473, 'post_switch_tracking_mm': 3.645, 'transparency_rmse_w': 2.310, 'pre_switch_transparency_w': 3.639, 'post_switch_transparency_w': 1.176, 'invalid_fraction': 0.0}])
display(ppod)
display(Image(filename=str(ROOT / 'results_index' / 'figures' / 'ppo_discrete_evaluation_bars.png')))
