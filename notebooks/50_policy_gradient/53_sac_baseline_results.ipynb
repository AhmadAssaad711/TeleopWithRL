# %% [markdown]
# # SAC baseline results
#
# Dedicated result notebook for [`53_sac_baseline.ipynb`](53_sac_baseline.ipynb).
#
# ## Result status
#
# The executed source notebook records the SAC run configuration, but no SAC numeric summary or reproducible evaluation artifact is present in the current checkout. Therefore no SAC model is promoted as a result and no evaluation graph is fabricated.
#
# | Item | Status |
# |---|---|
# | SAC run configuration | recorded in source notebook |
# | SAC evaluation summary | unavailable |
# | Best-model row | not reported |
# | Evaluation graph | not generated without numeric data |
#
# Run [`53_sac_baseline.ipynb`](53_sac_baseline.ipynb) after restoring the SAC result root, then add only its best model and bar-only evaluation graph here.

# %%
import pandas as pd
from IPython.display import display
status = pd.DataFrame([{'item': 'SAC run configuration', 'status': 'recorded in source notebook'}, {'item': 'SAC evaluation summary', 'status': 'unavailable'}, {'item': 'Best-model row', 'status': 'not reported'}, {'item': 'Evaluation graph', 'status': 'not generated without numeric data'}])
display(status)
