# %% [markdown]
# # DQN baseline results
#
# Dedicated result notebook for [`20_dqn_legacy_baseline.ipynb`](20_dqn_legacy_baseline.ipynb). Only the best recorded view from that notebook is shown: the switched-dynamics evaluation for `norm_legacy_trans_v1`.
#
# This is an archival result from the executed notebook output. The original DQN result directory is not tracked in the current checkout, so this row is not part of the reproducible current `runs.csv` catalog.
#
# ## Best recorded DQN result
#
# | Model | Mode | Tracking RMSE [mm] | Pre-switch [mm] | Post-switch [mm] | Transparency RMSE [W] | Pre-switch [W] | Post-switch [W] | Invalid episodes |
# |---|---|---:|---:|---:|---:|---:|---:|---:|
# | `DQN_baseline_norm_legacy_trans_v1_30s_10s` | switched dynamics | **47.260** | 26.543 | 54.754 | 7.520 | 8.224 | 7.142 | 0.0% |

# %% [markdown]
# ## Evaluation graph
#
# Evaluation is shown with bar graphs only.
#
# ![DQN best recorded evaluation bars](../../results_index/figures/dqn_best_evaluation_bars.png)

# %%
from pathlib import Path
import pandas as pd
from IPython.display import Image, display

ROOT = next(p for p in [Path.cwd().resolve(), *Path.cwd().resolve().parents] if (p / 'results_index').exists())
dqn = pd.DataFrame([{'model': 'DQN_baseline_norm_legacy_trans_v1_30s_10s', 'mode': 'switched dynamics', 'tracking_rmse_mm': 47.260, 'pre_switch_tracking_mm': 26.543, 'post_switch_tracking_mm': 54.754, 'transparency_rmse_w': 7.520, 'pre_switch_transparency_w': 8.224, 'post_switch_transparency_w': 7.142, 'invalid_fraction': 0.0}])
display(dqn)
display(Image(filename=str(ROOT / 'results_index' / 'figures' / 'dqn_best_evaluation_bars.png')))
